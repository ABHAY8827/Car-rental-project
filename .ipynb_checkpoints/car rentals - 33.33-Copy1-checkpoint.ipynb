# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('train_E1GspfA.csv')

# %%
data.head()
# Out:
#          date  hour  demand
# 0  2018-08-18     9      91
# 1  2018-08-18    10      21
# 2  2018-08-18    13      23
# 3  2018-08-18    14     104
# 4  2018-08-18    15      81

# %%
import pandas_datareader as pdr
from datetime import datetime

# %% [markdown]
# ## EDA(Exploratory data analysis)

# %%
data.plot(xlim=['2018-08-18','2019-08-18'],figsize=(10,4))
# Out:
# <AxesSubplot:>

# %%
data.plot(xlim=['2019-08-18','2020-08-18'],figsize=(10,4))
# Out:
# <AxesSubplot:>

# %%
data.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['date'] = pd.to_datetime(data['date'], errors='coerce')

# %%
data.head()
# Out:
#         date  hour  demand
# 0 2018-08-18     9      91
# 1 2018-08-18    10      21
# 2 2018-08-18    13      23
# 3 2018-08-18    14     104
# 4 2018-08-18    15      81

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## feature engineering

# %%
data['day-of-week'] = data['date'].dt.dayofweek

# %%
data['weak-of-year'] = data['date'].dt.weekofyear

# %%
data['month'] = pd.DatetimeIndex(data['date']).month

# %%
data['Quarter'] = data.date.dt.quarter

# %%
data['day_of_year'] = data.date.dt.day_of_year

# %%
data['year'] = data.date.dt.year

# %%
data['days_in_month'] = data.date.dt.days_in_month

# %%
data.head()
# Out:
#         date  hour  demand  day-of-week  weak-of-year  month  Quarter  \
# 0 2018-08-18     9      91            5            33      8        3
# 1 2018-08-18    10      21            5            33      8        3
# 2 2018-08-18    13      23            5            33      8        3
# 3 2018-08-18    14     104            5            33      8        3
# 4 2018-08-18    15      81            5            33      8        3
#
#    day_of_year  year  days_in_month
# 0          230  2018             31
# 1          230  2018             31
# 2          230  2018             31
# 3          230  2018             31
# 4          230  2018             31

# %% [markdown]
# #### 5 - saturday 6 -sunday and so on

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(y='demand',x='day-of-week',data=data)
# Out:
# <AxesSubplot:xlabel='day-of-week', ylabel='demand'>

# %%
sns.scatterplot(y='demand',x='hour',data=data)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='demand'>

# %%
sns.lineplot(y='demand',x='hour',data=data)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='demand'>

# %%
sns.lineplot(y='demand',x='day-of-week',data=data)
# Out:
# <AxesSubplot:xlabel='day-of-week', ylabel='demand'>

# %% [markdown]
# on day basis
# - #### 0 to 3 - low demand
# - #### 4 and 6 - medium demand
# - #### 5 - high demand
#
# reason can be that saturday and sunday office holiday soo can go for trips

# %% [markdown]
# - #### we can see that demand increases on friday to sunday and saturday the demand of rental cars is highest

# %%
demand_day = []
for i in range(len(data['day-of-week'])):
    if data['day-of-week'][i] <=3:
        demand_day.append("Low")
    else:
        demand_day.append("High")

# %%
data['demand_day'] = demand_day
data
# Out:
#             date  hour  demand  day-of-week  weak-of-year  month  Quarter  \
# 0     2018-08-18     9      91            5            33      8        3
# 1     2018-08-18    10      21            5            33      8        3
# 2     2018-08-18    13      23            5            33      8        3
# 3     2018-08-18    14     104            5            33      8        3
# 4     2018-08-18    15      81            5            33      8        3
# ...          ...   ...     ...          ...           ...    ...      ...
# 18242 2021-02-28    19      95            6             8      2        1
# 18243 2021-02-28    20      88            6             8      2        1
# 18244 2021-02-28    21      39            6             8      2        1
# 18245 2021-02-28    22     104            6             8      2        1
# 18246 2021-02-28    23      85            6             8      2        1
#
#        day_of_year  year  days_in_month demand_day
# 0              230  2018             31       High
# 1              230  2018             31       High
# 2              230  2018             31       High
# 3              230  2018             31       High
# 4              230  2018             31       High
# ...            ...   ...            ...        ...
# 18242           59  2021             28       High
# 18243           59  2021             28       High
# 18244           59  2021             28       High
# 18245           59  2021             28       High
# 18246           59  2021             28       High
#
# [18247 rows x 11 columns]

# %%
sns.barplot(y='demand',x='hour',data=data)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='demand'>

# %% [markdown]
# ## demand zone
# - low zone - 0-65
# - medium zone  65 -80
# - high zone 80 and above

# %% [markdown]
# ### on hour basis
# - #### 0 to 6 - demand in low
# - #### 6 to 12 - demand increase and reached in medium
# - #### 12 to 18 - demand increase and reached in highest
# - #### 18 to 22 - demand decreases and reached in medium
# - #### 22 to 24 - demand decreases and reached in low

# %%
# hour basis
demand_zone = []
for i in range(len(data['hour'])):
    if data['hour'][i] < 6 or data['hour'][i]>=22:
        demand_zone.append("Low")
    elif 6<=data['hour'][i]<=12 or 18<=data['hour'][i]<=22 :
        demand_zone.append("Medium")
    else:
        demand_zone.append("High")

# %%
data['demand_zone'] = demand_zone

# %%
data
# Out:
#             date  hour  demand  day-of-week  weak-of-year  month  Quarter  \
# 0     2018-08-18     9      91            5            33      8        3
# 1     2018-08-18    10      21            5            33      8        3
# 2     2018-08-18    13      23            5            33      8        3
# 3     2018-08-18    14     104            5            33      8        3
# 4     2018-08-18    15      81            5            33      8        3
# ...          ...   ...     ...          ...           ...    ...      ...
# 18242 2021-02-28    19      95            6             8      2        1
# 18243 2021-02-28    20      88            6             8      2        1
# 18244 2021-02-28    21      39            6             8      2        1
# 18245 2021-02-28    22     104            6             8      2        1
# 18246 2021-02-28    23      85            6             8      2        1
#
#        day_of_year  year  days_in_month demand_day demand_zone
# 0              230  2018             31       High      Medium
# 1              230  2018             31       High      Medium
# 2              230  2018             31       High        High
# 3              230  2018             31       High        High
# 4              230  2018             31       High        High
# ...            ...   ...            ...        ...         ...
# 18242           59  2021             28       High      Medium
# 18243           59  2021             28       High      Medium
# 18244           59  2021             28       High      Medium
# 18245           59  2021             28       High         Low
# 18246           59  2021             28       High         Low
#
# [18247 rows x 12 columns]

# %%
sns.barplot(x='demand_zone',y='demand',data=data)
# Out:
# <AxesSubplot:xlabel='demand_zone', ylabel='demand'>

# %%
sns.barplot(x='demand_day',y='demand',data=data)
# Out:
# <AxesSubplot:xlabel='demand_day', ylabel='demand'>

# %%
data.head()
# Out:
#         date  hour  demand  day-of-week  weak-of-year  month  Quarter  \
# 0 2018-08-18     9      91            5            33      8        3
# 1 2018-08-18    10      21            5            33      8        3
# 2 2018-08-18    13      23            5            33      8        3
# 3 2018-08-18    14     104            5            33      8        3
# 4 2018-08-18    15      81            5            33      8        3
#
#    day_of_year  year  days_in_month demand_day demand_zone
# 0          230  2018             31       High      Medium
# 1          230  2018             31       High      Medium
# 2          230  2018             31       High        High
# 3          230  2018             31       High        High
# 4          230  2018             31       High        High

# %%
from sklearn.preprocessing import LabelEncoder
lab_enc = LabelEncoder()
data['demand_day']= lab_enc.fit_transform(data['demand_day'])

# %%
data.head()
# Out:
#         date  hour  demand  day-of-week  weak-of-year  month  Quarter  \
# 0 2018-08-18     9      91            5            33      8        3
# 1 2018-08-18    10      21            5            33      8        3
# 2 2018-08-18    13      23            5            33      8        3
# 3 2018-08-18    14     104            5            33      8        3
# 4 2018-08-18    15      81            5            33      8        3
#
#    day_of_year  year  days_in_month  demand_day demand_zone
# 0          230  2018             31           0      Medium
# 1          230  2018             31           0      Medium
# 2          230  2018             31           0        High
# 3          230  2018             31           0        High
# 4          230  2018             31           0        High

# %%
data = pd.get_dummies(data)

# %%
data
# Out:
#             date  hour  demand  day-of-week  weak-of-year  month  Quarter  \
# 0     2018-08-18     9      91            5            33      8        3
# 1     2018-08-18    10      21            5            33      8        3
# 2     2018-08-18    13      23            5            33      8        3
# 3     2018-08-18    14     104            5            33      8        3
# 4     2018-08-18    15      81            5            33      8        3
# ...          ...   ...     ...          ...           ...    ...      ...
# 18242 2021-02-28    19      95            6             8      2        1
# 18243 2021-02-28    20      88            6             8      2        1
# 18244 2021-02-28    21      39            6             8      2        1
# 18245 2021-02-28    22     104            6             8      2        1
# 18246 2021-02-28    23      85            6             8      2        1
#
#        day_of_year  year  days_in_month  demand_day  demand_zone_High  \
# 0              230  2018             31           0                 0
# 1              230  2018             31           0                 0
# 2              230  2018             31           0                 1
# 3              230  2018             31           0                 1
# 4              230  2018             31           0                 1
# ...            ...   ...            ...         ...               ...
# 18242           59  2021             28           0                 0
# 18243           59  2021             28           0                 0
# 18244           59  2021             28           0                 0
# 18245           59  2021             28           0                 0
# 18246           59  2021             28           0                 0
#
#        demand_zone_Low  demand_zone_Medium
# 0                    0                   1
# 1                    0                   1
# 2                    0                   0
# 3                    0                   0
# 4                    0                   0
# ...                ...                 ...
# 18242                0                   1
# 18243                0                   1
# 18244                0                   1
# 18245                1                   0
# 18246                1                   0
#
# [18247 rows x 14 columns]

# %%
data['day-of-week'].unique()
# Out:
# array([5, 6, 0, 1, 2, 3, 4], dtype=int64)

# %%
X = data.drop(columns=['date','demand'])
y = data['demand']

# %%
X.shape
# Out:
# (18247, 12)

# %%
X
# Out:
#        hour  day-of-week  weak-of-year  month  Quarter  day_of_year  year  \
# 0         9            5            33      8        3          230  2018
# 1        10            5            33      8        3          230  2018
# 2        13            5            33      8        3          230  2018
# 3        14            5            33      8        3          230  2018
# 4        15            5            33      8        3          230  2018
# ...     ...          ...           ...    ...      ...          ...   ...
# 18242    19            6             8      2        1           59  2021
# 18243    20            6             8      2        1           59  2021
# 18244    21            6             8      2        1           59  2021
# 18245    22            6             8      2        1           59  2021
# 18246    23            6             8      2        1           59  2021
#
#        days_in_month  demand_day  demand_zone_High  demand_zone_Low  \
# 0                 31           0                 0                0
# 1                 31           0                 0                0
# 2                 31           0                 1                0
# 3                 31           0                 1                0
# 4                 31           0                 1                0
# ...              ...         ...               ...              ...
# 18242             28           0                 0                0
# 18243             28           0                 0                0
# 18244             28           0                 0                0
# 18245             28           0                 0                1
# 18246             28           0                 0                1
#
#        demand_zone_Medium
# 0                       1
# 1                       1
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 18242                   1
# 18243                   1
# 18244                   1
# 18245                   0
# 18246                   0
#
# [18247 rows x 12 columns]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error
import scikitplot as skplt

# %%
X
# Out:
#        hour  day-of-week  weak-of-year  month  Quarter  day_of_year  year  \
# 0         9            5            33      8        3          230  2018
# 1        10            5            33      8        3          230  2018
# 2        13            5            33      8        3          230  2018
# 3        14            5            33      8        3          230  2018
# 4        15            5            33      8        3          230  2018
# ...     ...          ...           ...    ...      ...          ...   ...
# 18242    19            6             8      2        1           59  2021
# 18243    20            6             8      2        1           59  2021
# 18244    21            6             8      2        1           59  2021
# 18245    22            6             8      2        1           59  2021
# 18246    23            6             8      2        1           59  2021
#
#        days_in_month  demand_day  demand_zone_High  demand_zone_Low  \
# 0                 31           0                 0                0
# 1                 31           0                 0                0
# 2                 31           0                 1                0
# 3                 31           0                 1                0
# 4                 31           0                 1                0
# ...              ...         ...               ...              ...
# 18242             28           0                 0                0
# 18243             28           0                 0                0
# 18244             28           0                 0                0
# 18245             28           0                 0                1
# 18246             28           0                 0                1
#
#        demand_zone_Medium
# 0                       1
# 1                       1
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 18242                   1
# 18243                   1
# 18244                   1
# 18245                   0
# 18246                   0
#
# [18247 rows x 12 columns]

# %%
from sklearn.metrics import mean_absolute_error
for i in range(0,1000):
    x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.10,random_state = i)
    lr.fit(x_train,y_train)
    pred_train = lr.predict(x_train) 
    pred_test = lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,1) == round(r2_score(y_test,pred_test)*100,1):
        print("At random state",i,"model perform very well")
        print("At random state",i)
        print('Training accuracy score is',r2_score(y_train,pred_train)*100)
        print('Testing accuracy score is',r2_score(y_test,pred_test)*100)
        mse = mean_squared_error(y_test,pred_test)
        print('RMSE :', np.sqrt(mse))
# Out:
# At random state 23 model perform very well
# At random state 23
# Training accuracy score is 13.778394198487687
# Testing accuracy score is 13.802067676520425
# RMSE : 37.46814102108324
# At random state 89 model perform very well
# At random state 89
# Training accuracy score is 13.775466961569505
# Testing accuracy score is 13.816599865043521
# RMSE : 38.350949482997194
# At random state 90 model perform very well
# At random state 90
# Training accuracy score is 13.775398479929923
# Testing accuracy score is 13.809017545194713
# RMSE : 37.29418662818411
# At random state 148 model perform very well
# At random state 148
# Training accuracy score is 13.780880443650211
# Testing accuracy score is 13.762074683698422
# RMSE : 39.21632811572628
# At random state 151 model perform very well
# At random state 151
# Training accuracy score is 13.778581002105096
# Testing accuracy score is 13.782621221144996
# RMSE : 39.544921516274044
# At random state 159 model perform very well
# At random state 159
# Training accuracy score is 13.76898324176058
# Testing accuracy score is 13.846309878211327
# RMSE : 37.456424395606945
# At random state 174 model perform very well
# At random state 174
# Training accuracy score is 13.768951501067573
# Testing accuracy score is 13.823264829583914
# RMSE : 37.79531478911386
# At random state 207 model perform very well
# At random state 207
# Training accuracy score is 13.776028802211759
# Testing accuracy score is 13.803965704610132
# RMSE : 38.037336152937584
# At random state 215 model perform very well
# At random state 215
# Training accuracy score is 13.767112534060622
# Testing accuracy score is 13.83858306823802
# RMSE : 38.336944761987034
# At random state 260 model perform very well
# At random state 260
# Training accuracy score is 13.779118730334982
# Testing accuracy score is 13.759382893384487
# RMSE : 38.77412761823332
# At random state 283 model perform very well
# At random state 283
# Training accuracy score is 13.762257645164489
# Testing accuracy score is 13.814182121093378
# RMSE : 39.161331558966836
# At random state 291 model perform very well
# At random state 291
# Training accuracy score is 13.766853816736635
# Testing accuracy score is 13.831744864884
# RMSE : 39.43840374280075
# At random state 298 model perform very well
# At random state 298
# Training accuracy score is 13.760194238448587
# Testing accuracy score is 13.830381008718929
# RMSE : 38.31194553966772
# At random state 307 model perform very well
# At random state 307
# Training accuracy score is 13.75004156460572
# Testing accuracy score is 13.836348399391674
# RMSE : 39.139643422267774
# At random state 309 model perform very well
# At random state 309
# Training accuracy score is 13.773070142470289
# Testing accuracy score is 13.791425431963944
# RMSE : 38.80921288880964
# At random state 322 model perform very well
# At random state 322
# Training accuracy score is 13.769575235701225
# Testing accuracy score is 13.823833209675563
# RMSE : 37.50917281252014
# At random state 350 model perform very well
# At random state 350
# Training accuracy score is 13.777424807474404
# Testing accuracy score is 13.788733217454785
# RMSE : 38.59006440501808
# At random state 369 model perform very well
# At random state 369
# Training accuracy score is 13.770420072474309
# Testing accuracy score is 13.77080545989503
# RMSE : 37.98934972295248
# At random state 391 model perform very well
# At random state 391
# Training accuracy score is 13.772632238864746
# Testing accuracy score is 13.811679975449454
# RMSE : 38.46066705678458
# At random state 409 model perform very well
# At random state 409
# Training accuracy score is 13.77450960015244
# Testing accuracy score is 13.832506614125585
# RMSE : 39.03748482799184
# At random state 504 model perform very well
# At random state 504
# Training accuracy score is 13.772047155103317
# Testing accuracy score is 13.784437487022295
# RMSE : 40.43899035617052
# At random state 528 model perform very well
# At random state 528
# Training accuracy score is 13.775232983987307
# Testing accuracy score is 13.788981493429542
# RMSE : 40.08433026415638
# At random state 604 model perform very well
# At random state 604
# Training accuracy score is 13.76521801612297
# Testing accuracy score is 13.840583558748765
# RMSE : 38.73670562752819
# At random state 668 model perform very well
# At random state 668
# Training accuracy score is 13.771813614188321
# Testing accuracy score is 13.80805968287503
# RMSE : 38.55520136130538
# At random state 685 model perform very well
# At random state 685
# Training accuracy score is 13.772492940277115
# Testing accuracy score is 13.817998605930736
# RMSE : 40.33841944467901
# At random state 775 model perform very well
# At random state 775
# Training accuracy score is 13.77624580422465
# Testing accuracy score is 13.788412992622156
# RMSE : 37.813913195203256
# At random state 856 model perform very well
# At random state 856
# Training accuracy score is 13.76152649398934
# Testing accuracy score is 13.847588019559575
# RMSE : 39.418693082864074
# At random state 903 model perform very well
# At random state 903
# Training accuracy score is 13.781015855797706
# Testing accuracy score is 13.755625303938235
# RMSE : 39.37728673373678
# At random state 926 model perform very well
# At random state 926
# Training accuracy score is 13.770535720329736
# Testing accuracy score is 13.847603008400977
# RMSE : 39.037452077186714
# At random state 953 model perform very well
# At random state 953
# Training accuracy score is 13.779311553042584
# Testing accuracy score is 13.756173936039296
# RMSE : 38.783787197056625
# At random state 963 model perform very well
# At random state 963
# Training accuracy score is 13.775608977525778
# Testing accuracy score is 13.836452965691649
# RMSE : 38.35263941954916

# %% [markdown]
# ## random_state = 925

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.10,random_state=90)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
lr = LinearRegression()
lr.fit(x_train,y_train)
pred = lr.predict(x_test)
print(r2_score(y_test,pred)*100)
print("mean_absolute_error",mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 13.809017545194713
# mean_absolute_error 29.162750342835796
# RMSE : 37.29418662818411

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
pred = rf.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 32.21120250011907
# 27.260893150684932
# RMSE : 33.07418789361151

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor()
gb.fit(x_train,y_train)
pred = gb.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 32.71803725520841
# 27.08395064054616
# RMSE : 32.950313452897454

# %%
from sklearn.ensemble import ExtraTreesRegressor
extg = ExtraTreesRegressor()
extg.fit(x_train,y_train)
pred = extg.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 19.244357956636936
# 29.59417534246575
# RMSE : 36.08728031292413

# %%
from xgboost import XGBRegressor
xgbt = XGBRegressor()
xgbt.fit(x_train,y_train)
pred = xgbt.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 38.10576226876417
# 26.442393765384203
# RMSE : 31.603511017690437

# %%
from sklearn.linear_model import RidgeCV
from sklearn.svm import LinearSVR

# %%
from sklearn.ensemble import StackingRegressor
estimators = [
('gb', GradientBoostingRegressor()),
('ext', ExtraTreesRegressor())]
reg = StackingRegressor(estimators=estimators,final_estimator=RandomForestRegressor(n_estimators=10,random_state=909))
reg.fit(x_train, y_train)
pred = reg.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 16.833548882571847
# 29.695671232876713
# RMSE : 36.621978280135075

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## hypertuning the model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rlf=RandomForestRegressor()
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=.10,random_state=90)
params = {'n_estimators':[100,125],
        'min_samples_split':[1,8],
        'min_samples_leaf':[1,5],
        'max_features': range(1,4),
        'min_impurity_decrease':np.arange(0.0,0.5),
        }
grd = GridSearchCV(rlf,param_grid = params)
grd.fit(x_train,y_train)
print('best_pram', grd.best_params_)

rf=grd.best_estimator_ #reinstantiating with best params

rf.fit(x_train,y_train)
pred = rf.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# best_pram {'max_features': 3, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 125}
# 37.66539166242744
# 26.49674610034226
# RMSE : 31.715739478361943

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(min_impurity_decrease=0.0,max_features=6, min_samples_leaf=1, 
                           min_samples_split=8,n_estimators=100,random_state=90,
                           ccp_alpha=0.50,criterion="squared_error")
rf.fit(x_train,y_train)
pred = rf.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 40.645569769635905
# 26.026915518688092
# RMSE : 30.94829974039789

# %%
"squared_error", "poisson"
# Out:
# ('squared_error', 'poisson')

# %%
from sklearn.model_selection import GridSearchCV

#creating parameter list to pass in Gridsearchcv
parameter ={'learning_rate': np.arange(0.1,0.3,0.1),
           'max_depth':range(2,8,2),
            'min_samples_split':range(2,4),
            'min_samples_leaf':range(1,7),
            'max_features':range(3,8),
            'n_estimators': range(100,140,5)
           }
grd = GridSearchCV(gb,param_grid = params)
grd.fit(x_train,y_train)
print('best_pram', grd.best_params_)

gb=grd.best_estimator_ #reinstantiating with best params

gb.fit(x_train,y_train)
pred = gb.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor( min_samples_leaf = 5, min_samples_split=8,random_state=859,ccp_alpha=0.0
                               ,max_features=4,n_estimators=125,learning_rate=0.30)
gb.fit(x_train,y_train)

pred = gb.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 35.609845207339966
# 26.692453524507343
# RMSE : 32.23442731430047

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(min_impurity_decrease=0.0,ccp_alpha=0.0,min_samples_split=2,random_state=859,max_depth=8,max_features=4)
dt.fit(x_train,y_train)
pred = dt.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 28.320248239851775
# 27.939896603478957
# RMSE : 34.01014398525353

# %%
test_data = pd.read_csv('test_6QvDdzb.csv')
test_data.head()
# Out:
#          date  hour
# 0  2021-03-01     0
# 1  2021-03-01     1
# 2  2021-03-01     2
# 3  2021-03-01     3
# 4  2021-03-01     5

# %%
test_data.shape
# Out:
# (7650, 2)

# %%
test_data['date'] = pd.to_datetime(test_data['date'], errors='coerce')

# %%
test_data['day-of-week'] = test_data['date'].dt.dayofweek

# %%
test_data['week-of-year'] = test_data['date'].dt.weekofyear

# %%
test_data['month'] = pd.DatetimeIndex(test_data['date']).month

# %%
test_data['Quarter'] = test_data.date.dt.quarter

# %%
test_data['day_of_year'] = test_data.date.dt.day_of_year

# %%
test_data['year'] = test_data.date.dt.year

# %%
test_data['days_in_month'] = test_data.date.dt.days_in_month

# %%
demand_day = []
for i in range(len(test_data['day-of-week'])):
    if test_data['day-of-week'][i] <=3:
        demand_day.append("Low")
    else:
        demand_day.append("High")

# %%
test_data['demand_day'] = demand_day

# %%
test_data
# Out:
#            date  hour  day-of-week  week-of-year  month  Quarter  day_of_year  \
# 0    2021-03-01     0            0             9      3        1           60
# 1    2021-03-01     1            0             9      3        1           60
# 2    2021-03-01     2            0             9      3        1           60
# 3    2021-03-01     3            0             9      3        1           60
# 4    2021-03-01     5            0             9      3        1           60
# ...         ...   ...          ...           ...    ...      ...          ...
# 7645 2022-03-28    19            0            13      3        1           87
# 7646 2022-03-28    20            0            13      3        1           87
# 7647 2022-03-28    21            0            13      3        1           87
# 7648 2022-03-28    22            0            13      3        1           87
# 7649 2022-03-28    23            0            13      3        1           87
#
#       year  days_in_month demand_day
# 0     2021             31        Low
# 1     2021             31        Low
# 2     2021             31        Low
# 3     2021             31        Low
# 4     2021             31        Low
# ...    ...            ...        ...
# 7645  2022             31        Low
# 7646  2022             31        Low
# 7647  2022             31        Low
# 7648  2022             31        Low
# 7649  2022             31        Low
#
# [7650 rows x 10 columns]

# %% [markdown]
# # changing in zones

# %%
demand_zone = []
for i in range(len(test_data['hour'])):
    if test_data['hour'][i] < 6 or test_data['hour'][i]>=22:
        demand_zone.append("Low")
    elif 6<=test_data['hour'][i]<=12 or 18<=test_data['hour'][i]<=22 :
        demand_zone.append("Medium")
    else:
        demand_zone.append("High")

# %%
test_data['demand_zone'] = demand_zone

# %%
### Label encoder in test data'
from sklearn.preprocessing import LabelEncoder
lab_enc = LabelEncoder()
test_data['demand_day'] = lab_enc.fit_transform(test_data['demand_day'])

# %%
test_data = pd.get_dummies(test_data)

# %%
test_data
# Out:
#            date  hour  day-of-week  week-of-year  month  Quarter  day_of_year  \
# 0    2021-03-01     0            0             9      3        1           60
# 1    2021-03-01     1            0             9      3        1           60
# 2    2021-03-01     2            0             9      3        1           60
# 3    2021-03-01     3            0             9      3        1           60
# 4    2021-03-01     5            0             9      3        1           60
# ...         ...   ...          ...           ...    ...      ...          ...
# 7645 2022-03-28    19            0            13      3        1           87
# 7646 2022-03-28    20            0            13      3        1           87
# 7647 2022-03-28    21            0            13      3        1           87
# 7648 2022-03-28    22            0            13      3        1           87
# 7649 2022-03-28    23            0            13      3        1           87
#
#       year  days_in_month  demand_day  demand_zone_High  demand_zone_Low  \
# 0     2021             31           1                 0                1
# 1     2021             31           1                 0                1
# 2     2021             31           1                 0                1
# 3     2021             31           1                 0                1
# 4     2021             31           1                 0                1
# ...    ...            ...         ...               ...              ...
# 7645  2022             31           1                 0                0
# 7646  2022             31           1                 0                0
# 7647  2022             31           1                 0                0
# 7648  2022             31           1                 0                1
# 7649  2022             31           1                 0                1
#
#       demand_zone_Medium
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 7645                   1
# 7646                   1
# 7647                   1
# 7648                   0
# 7649                   0
#
# [7650 rows x 13 columns]

# %%
X_test = test_data.drop(columns=['date'])

# %%
X_test.shape
# Out:
# (7650, 12)

# %%
pred = rf.predict(X_test)

# %%
pred
# Out:
# array([54.57677647, 52.67309399, 52.69223685, ..., 67.13878376,
#        55.32794238, 55.28980914])

# %%
submission_file = pd.read_csv('sample_4E0BhPN.csv')

# %%
submission_file.shape
# Out:
# (7650, 3)

# %%
submission_file['demand'] = pred

# %%
pred.shape
# Out:
# (7650,)

# %%
submission_file
# Out:
#             date  hour     demand
# 0     2021-03-01     0  54.576776
# 1     2021-03-01     1  52.673094
# 2     2021-03-01     2  52.692237
# 3     2021-03-01     3  52.811372
# 4     2021-03-01     5  51.711462
# ...          ...   ...        ...
# 7645  2022-03-28    19  81.909361
# 7646  2022-03-28    20  76.094214
# 7647  2022-03-28    21  67.138784
# 7648  2022-03-28    22  55.327942
# 7649  2022-03-28    23  55.289809
#
# [7650 rows x 3 columns]

# %%
submission_file.to_csv("rf 42 model.csv",index=False)

# %%
submission_file.shape
# Out:
# (7650, 3)
