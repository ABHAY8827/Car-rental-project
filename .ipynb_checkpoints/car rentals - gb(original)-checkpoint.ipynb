# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('train_E1GspfA.csv')

# %%
data.head()
# Out:
#          date  hour  demand
# 0  2018-08-18     9      91
# 1  2018-08-18    10      21
# 2  2018-08-18    13      23
# 3  2018-08-18    14     104
# 4  2018-08-18    15      81

# %%
import pandas_datareader as pdr
from datetime import datetime

# %%
data.plot(xlim=['2018-08-18','2019-08-18'],figsize=(10,4))
# Out:
# <AxesSubplot:>

# %%
data.plot(xlim=['2019-08-18','2020-08-18'],figsize=(10,4))
# Out:
# <AxesSubplot:>

# %%
data.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
X = data['hour']
y = data['demand']

# %%
X.shape
# Out:
# (18247,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error
import scikitplot as skplt

# %%
X = np.array(X)

# %%
X = X.reshape(-1,1)

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.10,random_state = i)
    lr.fit(x_train,y_train)
    pred_train = lr.predict(x_train) 
    pred_test = lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,1) == round(r2_score(y_test,pred_test)*100,1):
        print("At random state",i,"model perform very well")
        print("At random state",i)
        print('Training accuracy score is',r2_score(y_train,pred_train)*100)
        print('Testing accuracy score is',r2_score(y_test,pred_test)*100)
# Out:
# At random state 28 model perform very well
# At random state 28
# Training accuracy score is 2.613207433097531
# Testing accuracy score is 2.561022094139076
# At random state 71 model perform very well
# At random state 71
# Training accuracy score is 2.6075217685576746
# Testing accuracy score is 2.586391620318018
# At random state 83 model perform very well
# At random state 83
# Training accuracy score is 2.6012246893836632
# Testing accuracy score is 2.605431358272592
# At random state 142 model perform very well
# At random state 142
# Training accuracy score is 2.6018098007898782
# Testing accuracy score is 2.6128775044305774
# At random state 149 model perform very well
# At random state 149
# Training accuracy score is 2.597638051576967
# Testing accuracy score is 2.6090999154606997
# At random state 161 model perform very well
# At random state 161
# Training accuracy score is 2.611592637717708
# Testing accuracy score is 2.567192078391567
# At random state 177 model perform very well
# At random state 177
# Training accuracy score is 2.5986515990387926
# Testing accuracy score is 2.637594249927566
# At random state 181 model perform very well
# At random state 181
# Training accuracy score is 2.609046211431587
# Testing accuracy score is 2.5999740580241015
# At random state 200 model perform very well
# At random state 200
# Training accuracy score is 2.6007512028390356
# Testing accuracy score is 2.638728458434625
# At random state 213 model perform very well
# At random state 213
# Training accuracy score is 2.6034590225879173
# Testing accuracy score is 2.6492567015293678
# At random state 296 model perform very well
# At random state 296
# Training accuracy score is 2.6001965736741184
# Testing accuracy score is 2.641493117029181
# At random state 298 model perform very well
# At random state 298
# Training accuracy score is 2.594042335018576
# Testing accuracy score is 2.578715930631781
# At random state 302 model perform very well
# At random state 302
# Training accuracy score is 2.6104174719183804
# Testing accuracy score is 2.5828366569555783
# At random state 344 model perform very well
# At random state 344
# Training accuracy score is 2.576728679127216
# Testing accuracy score is 2.6206337274307434
# At random state 347 model perform very well
# At random state 347
# Training accuracy score is 2.6129815883286
# Testing accuracy score is 2.566184998691634
# At random state 360 model perform very well
# At random state 360
# Training accuracy score is 2.601204132052981
# Testing accuracy score is 2.60353701237811
# At random state 436 model perform very well
# At random state 436
# Training accuracy score is 2.6095328556100417
# Testing accuracy score is 2.594682166875162
# At random state 446 model perform very well
# At random state 446
# Training accuracy score is 2.6067671472416953
# Testing accuracy score is 2.5809259736220835
# At random state 453 model perform very well
# At random state 453
# Training accuracy score is 2.608082954520541
# Testing accuracy score is 2.579347810537913
# At random state 458 model perform very well
# At random state 458
# Training accuracy score is 2.6119746943324085
# Testing accuracy score is 2.5524086385300238
# At random state 580 model perform very well
# At random state 580
# Training accuracy score is 2.6134851931793768
# Testing accuracy score is 2.553940279115152
# At random state 607 model perform very well
# At random state 607
# Training accuracy score is 2.6067999491259153
# Testing accuracy score is 2.596717008094196
# At random state 636 model perform very well
# At random state 636
# Training accuracy score is 2.6065510710766793
# Testing accuracy score is 2.572550933592921
# At random state 645 model perform very well
# At random state 645
# Training accuracy score is 2.6055815535821036
# Testing accuracy score is 2.629496188599112
# At random state 665 model perform very well
# At random state 665
# Training accuracy score is 2.601698726945534
# Testing accuracy score is 2.5844345713019745
# At random state 698 model perform very well
# At random state 698
# Training accuracy score is 2.6008722416348884
# Testing accuracy score is 2.553526119145111
# At random state 719 model perform very well
# At random state 719
# Training accuracy score is 2.607425472582936
# Testing accuracy score is 2.6142732358989007
# At random state 771 model perform very well
# At random state 771
# Training accuracy score is 2.6021744667433677
# Testing accuracy score is 2.6416543366039824
# At random state 775 model perform very well
# At random state 775
# Training accuracy score is 2.6021383010228827
# Testing accuracy score is 2.582532186256381
# At random state 779 model perform very well
# At random state 779
# Training accuracy score is 2.609967815394121
# Testing accuracy score is 2.553376383446049
# At random state 786 model perform very well
# At random state 786
# Training accuracy score is 2.604622886057817
# Testing accuracy score is 2.6396992117543427
# At random state 806 model perform very well
# At random state 806
# Training accuracy score is 2.611905244892321
# Testing accuracy score is 2.5748816361708227
# At random state 842 model perform very well
# At random state 842
# Training accuracy score is 2.594730910134546
# Testing accuracy score is 2.5900514124009733
# At random state 859 model perform very well
# At random state 859
# Training accuracy score is 2.589877616228875
# Testing accuracy score is 2.6188873150541636
# At random state 871 model perform very well
# At random state 871
# Training accuracy score is 2.6063821949144472
# Testing accuracy score is 2.616222813700242
# At random state 873 model perform very well
# At random state 873
# Training accuracy score is 2.6088643498669906
# Testing accuracy score is 2.5631536437546454
# At random state 880 model perform very well
# At random state 880
# Training accuracy score is 2.5973180349291525
# Testing accuracy score is 2.6055047924478325
# At random state 891 model perform very well
# At random state 891
# Training accuracy score is 2.612556311910441
# Testing accuracy score is 2.557865261997694
# At random state 894 model perform very well
# At random state 894
# Training accuracy score is 2.605737457929802
# Testing accuracy score is 2.6170624125813835
# At random state 919 model perform very well
# At random state 919
# Training accuracy score is 2.59899821450994
# Testing accuracy score is 2.6373605868534877
# At random state 940 model perform very well
# At random state 940
# Training accuracy score is 2.598220425318176
# Testing accuracy score is 2.5827180685633278
# At random state 960 model perform very well
# At random state 960
# Training accuracy score is 2.6080234897299492
# Testing accuracy score is 2.55935415877131
# At random state 973 model perform very well
# At random state 973
# Training accuracy score is 2.606460926622911
# Testing accuracy score is 2.6210436362150147

# %% [markdown]
# ## random_state = 302

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=859)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
lr = LinearRegression()
lr.fit(x_train,y_train)
pred = lr.predict(x_test)
print(r2_score(y_test,pred)*100)
print("mean_absolute_error",mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 2.4960679675305686
# mean_absolute_error 32.216628093843816
# RMSE : 40.91656578893621

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
pred = rf.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 12.611671964900118
# 30.78112231480559
# RMSE : 38.736004769059605

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor()
gb.fit(x_train,y_train)
pred = gb.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 12.624036691263008
# 30.77792091528472
# RMSE : 38.733264259808806

# %%
from xgboost import XGBRegressor
xgbt = GradientBoostingRegressor()
xgbt.fit(x_train,y_train)
pred = xgbt.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 12.624036691263008
# 30.77792091528472
# RMSE : 38.733264259808806

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(x_train,y_train)
pred_svr = svr.predict(x_test)
print(r2_score(y_test,pred_svr)*100)
print(mean_absolute_error(y_test,pred_svr))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 12.25033344633928
# 30.781350187662422
# RMSE : 38.733264259808806

# %%
test_data = pd.read_csv('test_6QvDdzb.csv')
test_data.head()
# Out:
#          date  hour
# 0  2021-03-01     0
# 1  2021-03-01     1
# 2  2021-03-01     2
# 3  2021-03-01     3
# 4  2021-03-01     5

# %%
test_data.shape
# Out:
# (7650, 2)

# %%
X_test = test_data['hour']

# %%
X_test = np.array(X_test)
X_test = X_test.reshape(-1,1)

# %%
X_test.shape
# Out:
# (7650, 1)

# %%
pred = gb.predict(X_test)

# %%
pred
# Out:
# array([57.66732436, 56.14560187, 56.7153461 , ..., 68.04444891,
#        63.97812146, 59.37701184])

# %%
submission_file = pd.read_csv('sample_4E0BhPN.csv')
submission_file
# Out:
#             date  hour  demand
# 0     2021-03-01     0       0
# 1     2021-03-01     1       0
# 2     2021-03-01     2       0
# 3     2021-03-01     3       0
# 4     2021-03-01     5       0
# ...          ...   ...     ...
# 7645  2022-03-28    19       0
# 7646  2022-03-28    20       0
# 7647  2022-03-28    21       0
# 7648  2022-03-28    22       0
# 7649  2022-03-28    23       0
#
# [7650 rows x 3 columns]

# %%
submission_file.shape
# Out:
# (7650, 3)

# %%
submission_file['demand'] = pred.astype('int')

# %%
pred.shape
# Out:
# (7650,)

# %%
submission_file
# Out:
#             date  hour  demand
# 0     2021-03-01     0      57
# 1     2021-03-01     1      56
# 2     2021-03-01     2      56
# 3     2021-03-01     3      56
# 4     2021-03-01     5      48
# ...          ...   ...     ...
# 7645  2022-03-28    19      80
# 7646  2022-03-28    20      70
# 7647  2022-03-28    21      68
# 7648  2022-03-28    22      63
# 7649  2022-03-28    23      59
#
# [7650 rows x 3 columns]

# %%
submission_file.to_csv("1st_file_gb.csv",index=False)

# %%
submission_file.shape
# Out:
# (7650, 3)
