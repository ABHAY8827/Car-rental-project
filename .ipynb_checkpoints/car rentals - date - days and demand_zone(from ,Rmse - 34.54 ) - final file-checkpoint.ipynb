# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('train_E1GspfA.csv')

# %%
data.head()
# Out:
#          date  hour  demand
# 0  2018-08-18     9      91
# 1  2018-08-18    10      21
# 2  2018-08-18    13      23
# 3  2018-08-18    14     104
# 4  2018-08-18    15      81

# %%
import pandas_datareader as pdr
from datetime import datetime

# %%
data.plot(xlim=['2018-08-18','2019-08-18'],figsize=(10,4))
# Out:
# <AxesSubplot:>

# %%
data.plot(xlim=['2019-08-18','2020-08-18'],figsize=(10,4))
# Out:
# <AxesSubplot:>

# %%
data.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['date'] = pd.to_datetime(data['date'], errors='coerce')

# %%
data.head()
# Out:
#         date  hour  demand
# 0 2018-08-18     9      91
# 1 2018-08-18    10      21
# 2 2018-08-18    13      23
# 3 2018-08-18    14     104
# 4 2018-08-18    15      81

# %%
data['day-of-week'] = data['date'].dt.dayofweek

# %%
data['weak-of-year'] = data['date'].dt.weekofyear
# Out:
# <ipython-input-12-baa4b91e2b43>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   data['weak-of-year'] = data['date'].dt.weekofyear

# %%
data
# Out:
#             date  hour  demand  day-of-week  weak-of-year
# 0     2018-08-18     9      91            5            33
# 1     2018-08-18    10      21            5            33
# 2     2018-08-18    13      23            5            33
# 3     2018-08-18    14     104            5            33
# 4     2018-08-18    15      81            5            33
# ...          ...   ...     ...          ...           ...
# 18242 2021-02-28    19      95            6             8
# 18243 2021-02-28    20      88            6             8
# 18244 2021-02-28    21      39            6             8
# 18245 2021-02-28    22     104            6             8
# 18246 2021-02-28    23      85            6             8
#
# [18247 rows x 5 columns]

# %% [markdown]
# #### 5 - saturday 6 -sunday and so on

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(y='demand',x='day-of-week',data=data)
# Out:
# <AxesSubplot:xlabel='day-of-week', ylabel='demand'>

# %%
sns.scatterplot(y='demand',x='hour',data=data)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='demand'>

# %%
sns.lineplot(y='demand',x='hour',data=data)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='demand'>

# %%
sns.lineplot(y='demand',x='day-of-week',data=data)
# Out:
# <AxesSubplot:xlabel='day-of-week', ylabel='demand'>

# %% [markdown]
# on day basis
# - #### 0 to 3 - low demand
# - #### 4 and 6 - medium demand
# - #### 5 - high demand
#
# reason can be that saturday and sunday office holiday soo can go for trips

# %% [markdown]
# - #### we can see that demand increases on friday to sunday and saturday the demand of rental cars is highest

# %%
demand_day = []
for i in range(len(data['day-of-week'])):
    if data['day-of-week'][i] <=3:
        demand_day.append("Low")
    else:
        demand_day.append("High")

# %%
data['demand_day'] = demand_day
data
# Out:
#             date  hour  demand  day-of-week  weak-of-year demand_day
# 0     2018-08-18     9      91            5            33       High
# 1     2018-08-18    10      21            5            33       High
# 2     2018-08-18    13      23            5            33       High
# 3     2018-08-18    14     104            5            33       High
# 4     2018-08-18    15      81            5            33       High
# ...          ...   ...     ...          ...           ...        ...
# 18242 2021-02-28    19      95            6             8       High
# 18243 2021-02-28    20      88            6             8       High
# 18244 2021-02-28    21      39            6             8       High
# 18245 2021-02-28    22     104            6             8       High
# 18246 2021-02-28    23      85            6             8       High
#
# [18247 rows x 6 columns]

# %%
sns.barplot(y='demand',x='hour',data=data)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='demand'>

# %% [markdown]
# ## demand zone
# - low zone - 0-65
# - medium zone  65 -80
# - high zone 80 and above

# %% [markdown]
# ### on hour basis
# - #### 0 to 6 - demand in low
# - #### 6 to 12 - demand increase and reached in medium
# - #### 12 to 18 - demand increase and reached in highest
# - #### 18 to 22 - demand decreases and reached in medium
# - #### 22 to 24 - demand decreases and reached in low

# %%
# hour basis
demand_zone = []
for i in range(len(data['hour'])):
    if data['hour'][i] < 6 or data['hour'][i]>=22:
        demand_zone.append("Low")
    elif 6<=data['hour'][i]<=12 or 18<=data['hour'][i]<=22 :
        demand_zone.append("Medium")
    else:
        demand_zone.append("High")

# %%
data['demand_zone'] = demand_zone

# %%
data
# Out:
#             date  hour  demand  day-of-week  weak-of-year demand_day  \
# 0     2018-08-18     9      91            5            33       High
# 1     2018-08-18    10      21            5            33       High
# 2     2018-08-18    13      23            5            33       High
# 3     2018-08-18    14     104            5            33       High
# 4     2018-08-18    15      81            5            33       High
# ...          ...   ...     ...          ...           ...        ...
# 18242 2021-02-28    19      95            6             8       High
# 18243 2021-02-28    20      88            6             8       High
# 18244 2021-02-28    21      39            6             8       High
# 18245 2021-02-28    22     104            6             8       High
# 18246 2021-02-28    23      85            6             8       High
#
#       demand_zone
# 0          Medium
# 1          Medium
# 2            High
# 3            High
# 4            High
# ...           ...
# 18242      Medium
# 18243      Medium
# 18244      Medium
# 18245         Low
# 18246         Low
#
# [18247 rows x 7 columns]

# %%
sns.barplot(x='demand_zone',y='demand',data=data)
# Out:
# <AxesSubplot:xlabel='demand_zone', ylabel='demand'>

# %%
sns.barplot(x='demand_day',y='demand',data=data)
# Out:
# <AxesSubplot:xlabel='demand_day', ylabel='demand'>

# %%
data.head()
# Out:
#         date  hour  demand  day-of-week  weak-of-year demand_day demand_zone
# 0 2018-08-18     9      91            5            33       High      Medium
# 1 2018-08-18    10      21            5            33       High      Medium
# 2 2018-08-18    13      23            5            33       High        High
# 3 2018-08-18    14     104            5            33       High        High
# 4 2018-08-18    15      81            5            33       High        High

# %%
from sklearn.preprocessing import LabelEncoder
lab_enc = LabelEncoder()
data['demand_day']= lab_enc.fit_transform(data['demand_day'])

# %% [markdown]
# ### LABEL ENCODER
# from sklearn.preprocessing import OrdinalEncoder
# ord_enc = OrdinalEncoder(categories=[['High','Low'],[1,0]])
# df1= ord_enc.fit_transform(data[['demand_zone','demand_day']])
# df1

# %%
data.head()
# Out:
#         date  hour  demand  day-of-week  weak-of-year  demand_day demand_zone
# 0 2018-08-18     9      91            5            33           0      Medium
# 1 2018-08-18    10      21            5            33           0      Medium
# 2 2018-08-18    13      23            5            33           0        High
# 3 2018-08-18    14     104            5            33           0        High
# 4 2018-08-18    15      81            5            33           0        High

# %%
data = pd.get_dummies(data)

# %%
data
# Out:
#             date  hour  demand  day-of-week  weak-of-year  demand_day  \
# 0     2018-08-18     9      91            5            33           0
# 1     2018-08-18    10      21            5            33           0
# 2     2018-08-18    13      23            5            33           0
# 3     2018-08-18    14     104            5            33           0
# 4     2018-08-18    15      81            5            33           0
# ...          ...   ...     ...          ...           ...         ...
# 18242 2021-02-28    19      95            6             8           0
# 18243 2021-02-28    20      88            6             8           0
# 18244 2021-02-28    21      39            6             8           0
# 18245 2021-02-28    22     104            6             8           0
# 18246 2021-02-28    23      85            6             8           0
#
#        demand_zone_High  demand_zone_Low  demand_zone_Medium
# 0                     0                0                   1
# 1                     0                0                   1
# 2                     1                0                   0
# 3                     1                0                   0
# 4                     1                0                   0
# ...                 ...              ...                 ...
# 18242                 0                0                   1
# 18243                 0                0                   1
# 18244                 0                0                   1
# 18245                 0                1                   0
# 18246                 0                1                   0
#
# [18247 rows x 9 columns]

# %%
##from sklearn.preprocessing import OrdinalEncoder
#enc = OrdinalEncoder()
#X = [['Low', 0], ['High', 2], ['Medium', 3]]
# enc.fit(X)

# %%
#dz = np.array(data['demand_zone'])
#dz = dz.reshape(-1,1)

# %%
#dz= enc.fit_transform(dz)

# %%
#data['demand_zone'] = dz

# %%
#data.head()

# %%
data['day-of-week'].unique()
# Out:
# array([5, 6, 0, 1, 2, 3, 4], dtype=int64)

# %%
X = data.drop(columns=['date','demand'])
y = data['demand']

# %%
X.shape
# Out:
# (18247, 7)

# %%
X
# Out:
#        hour  day-of-week  weak-of-year  demand_day  demand_zone_High  \
# 0         9            5            33           0                 0
# 1        10            5            33           0                 0
# 2        13            5            33           0                 1
# 3        14            5            33           0                 1
# 4        15            5            33           0                 1
# ...     ...          ...           ...         ...               ...
# 18242    19            6             8           0                 0
# 18243    20            6             8           0                 0
# 18244    21            6             8           0                 0
# 18245    22            6             8           0                 0
# 18246    23            6             8           0                 0
#
#        demand_zone_Low  demand_zone_Medium
# 0                    0                   1
# 1                    0                   1
# 2                    0                   0
# 3                    0                   0
# 4                    0                   0
# ...                ...                 ...
# 18242                0                   1
# 18243                0                   1
# 18244                0                   1
# 18245                1                   0
# 18246                1                   0
#
# [18247 rows x 7 columns]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error
import scikitplot as skplt

# %%
# X = np.array(X)

# %%
# X = X.reshape(-1,1)

# %%
X
# Out:
#        hour  day-of-week  weak-of-year  demand_day  demand_zone_High  \
# 0         9            5            33           0                 0
# 1        10            5            33           0                 0
# 2        13            5            33           0                 1
# 3        14            5            33           0                 1
# 4        15            5            33           0                 1
# ...     ...          ...           ...         ...               ...
# 18242    19            6             8           0                 0
# 18243    20            6             8           0                 0
# 18244    21            6             8           0                 0
# 18245    22            6             8           0                 0
# 18246    23            6             8           0                 0
#
#        demand_zone_Low  demand_zone_Medium
# 0                    0                   1
# 1                    0                   1
# 2                    0                   0
# 3                    0                   0
# 4                    0                   0
# ...                ...                 ...
# 18242                0                   1
# 18243                0                   1
# 18244                0                   1
# 18245                1                   0
# 18246                1                   0
#
# [18247 rows x 7 columns]

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.10,random_state = i)
    lr.fit(x_train,y_train)
    pred_train = lr.predict(x_train) 
    pred_test = lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,1) == round(r2_score(y_test,pred_test)*100,1):
        print("At random state",i,"model perform very well")
        print("At random state",i)
        print('Training accuracy score is',r2_score(y_train,pred_train)*100)
        print('Testing accuracy score is',r2_score(y_test,pred_test)*100)
# Out:
# At random state 29 model perform very well
# At random state 29
# Training accuracy score is 12.602957140352778
# Testing accuracy score is 12.551872641920781
# At random state 94 model perform very well
# At random state 94
# Training accuracy score is 12.599981140153616
# Testing accuracy score is 12.561505655900596
# At random state 101 model perform very well
# At random state 101
# Training accuracy score is 12.586336415750598
# Testing accuracy score is 12.576482270366874
# At random state 122 model perform very well
# At random state 122
# Training accuracy score is 12.583264288581542
# Testing accuracy score is 12.620945270297113
# At random state 178 model perform very well
# At random state 178
# Training accuracy score is 12.592243310072549
# Testing accuracy score is 12.646593963213393
# At random state 217 model perform very well
# At random state 217
# Training accuracy score is 12.600140781381498
# Testing accuracy score is 12.586364945400863
# At random state 225 model perform very well
# At random state 225
# Training accuracy score is 12.592858010155439
# Testing accuracy score is 12.632411432742652
# At random state 239 model perform very well
# At random state 239
# Training accuracy score is 12.593744644730398
# Testing accuracy score is 12.640068372215074
# At random state 334 model perform very well
# At random state 334
# Training accuracy score is 12.584058351159433
# Testing accuracy score is 12.645054660221023
# At random state 335 model perform very well
# At random state 335
# Training accuracy score is 12.57785908003598
# Testing accuracy score is 12.597879079014529
# At random state 418 model perform very well
# At random state 418
# Training accuracy score is 12.596859558780215
# Testing accuracy score is 12.584187441316386
# At random state 486 model perform very well
# At random state 486
# Training accuracy score is 12.595108084114305
# Testing accuracy score is 12.558786575332059
# At random state 503 model perform very well
# At random state 503
# Training accuracy score is 12.598039659303417
# Testing accuracy score is 12.615096938049586
# At random state 560 model perform very well
# At random state 560
# Training accuracy score is 12.562881625418099
# Testing accuracy score is 12.62216174173586
# At random state 599 model perform very well
# At random state 599
# Training accuracy score is 12.593907146110805
# Testing accuracy score is 12.639560058213162
# At random state 643 model perform very well
# At random state 643
# Training accuracy score is 12.598866966983845
# Testing accuracy score is 12.595273231362537
# At random state 672 model perform very well
# At random state 672
# Training accuracy score is 12.581018883663731
# Testing accuracy score is 12.635988537902175
# At random state 685 model perform very well
# At random state 685
# Training accuracy score is 12.59912096772352
# Testing accuracy score is 12.599222700215051
# At random state 690 model perform very well
# At random state 690
# Training accuracy score is 12.59863743085613
# Testing accuracy score is 12.571209226332137
# At random state 694 model perform very well
# At random state 694
# Training accuracy score is 12.603785993442173
# Testing accuracy score is 12.566969894058333
# At random state 697 model perform very well
# At random state 697
# Training accuracy score is 12.601697768362785
# Testing accuracy score is 12.580355360606077
# At random state 775 model perform very well
# At random state 775
# Training accuracy score is 12.591126586635426
# Testing accuracy score is 12.61494959290632
# At random state 805 model perform very well
# At random state 805
# Training accuracy score is 12.602325403846404
# Testing accuracy score is 12.585399340707982
# At random state 854 model perform very well
# At random state 854
# Training accuracy score is 12.60192300209545
# Testing accuracy score is 12.556028390672424
# At random state 865 model perform very well
# At random state 865
# Training accuracy score is 12.592239169205332
# Testing accuracy score is 12.616418549577501
# At random state 869 model perform very well
# At random state 869
# Training accuracy score is 12.557787765388639
# Testing accuracy score is 12.576364022422926
# At random state 898 model perform very well
# At random state 898
# Training accuracy score is 12.599937777631997
# Testing accuracy score is 12.577534488399134
# At random state 925 model perform very well
# At random state 925
# Training accuracy score is 12.593158563150652
# Testing accuracy score is 12.623950920258354
# At random state 933 model perform very well
# At random state 933
# Training accuracy score is 12.593287854642776
# Testing accuracy score is 12.647739306527594
# At random state 953 model perform very well
# At random state 953
# Training accuracy score is 12.587261744050393
# Testing accuracy score is 12.64666517397568
# At random state 963 model perform very well
# At random state 963
# Training accuracy score is 12.594721315760326
# Testing accuracy score is 12.634174981154288
# At random state 980 model perform very well
# At random state 980
# Training accuracy score is 12.600646550304162
# Testing accuracy score is 12.55676067553333

# %% [markdown]
# ## random_state = 925

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.10,random_state=980)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
lr = LinearRegression()
lr.fit(x_train,y_train)
pred = lr.predict(x_test)
print(r2_score(y_test,pred)*100)
print("mean_absolute_error",mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 12.55676067553333
# mean_absolute_error 30.33047932446691
# RMSE : 39.79479184431922

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
pred = rf.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 11.79465420826854
# 32.03012954298365
# RMSE : 39.96783023281453

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor()
gb.fit(x_train,y_train)
pred = gb.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 30.90479852649558
# 28.728119532983712
# RMSE : 35.37423546375547

# %%
from sklearn.ensemble import ExtraTreesRegressor
extg = ExtraTreesRegressor()
extg.fit(x_train,y_train)
pred = extg.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# -8.546438227708663
# 35.232822121944665
# RMSE : 44.33746996060542

# %%
from xgboost import XGBRegressor
xgbt = XGBRegressor()
xgbt.fit(x_train,y_train)
pred = xgbt.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 32.2463318688055
# 28.630583003841036
# RMSE : 35.02914401188788

# %%
from sklearn.linear_model import RidgeCV
from sklearn.svm import LinearSVR

# %%
from sklearn.ensemble import StackingRegressor
estimators = [
('gb', GradientBoostingRegressor()),
('ext', ExtraTreesRegressor())]
reg = StackingRegressor(estimators=estimators,final_estimator=RandomForestRegressor(n_estimators=20,random_state=909))
reg.fit(x_train, y_train)
pred = reg.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 19.09309033083344
# 30.52239603174603
# RMSE : 38.27858938699543

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## hypertuning the model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rlf=RandomForestRegressor()
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=.10,random_state=859)
params = {'n_estimators':[100,125],
        'min_samples_split':[1,8],
        'min_samples_leaf':[1,5],
        'max_features': range(1,4),
        'min_impurity_decrease':np.arange(0.0,0.5),
        'ccp_alpha':np.arange(0.0,1.0,0.10)
        }
grd = GridSearchCV(rlf,param_grid = params)
grd.fit(x_train,y_train)
print('best_pram', grd.best_params_)

rf=grd.best_estimator_ #reinstantiating with best params

rf.fit(x_train,y_train)
pred = rf.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# best_pram {'ccp_alpha': 0.7000000000000001, 'max_features': 3, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 125}
# 18.233108290651856
# 29.935179343782508
# RMSE : 37.11317016663169

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(min_impurity_decrease=0.0,max_features=4, min_samples_leaf=1, min_samples_split=8,n_estimators=130,ccp_alpha=0.7,random_state=859)
rf.fit(x_train,y_train)
pred = rf.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 34.16373100104393
# 28.089479036934883
# RMSE : 34.52993207813308

# %%
from sklearn.model_selection import GridSearchCV

#creating parameter list to pass in Gridsearchcv
parameter ={'learning_rate': np.arange(0.1,0.3,0.1),
           'max_depth':range(2,8,2),
            'min_samples_split':range(2,4),
            'min_samples_leaf':range(1,7)
           }
GCV = GridSearchCV(gb,parameter,cv=5,scoring='accuracy')

GCV.fit(x_train,y_train)  #fitting the data in model
GCV.best_params_          #printing the best parameter found by Gridsearchcv
GCV_pred = GCV.best_estimator_.predict(x_test)    #predicting with best parameter 
# finding the mean squared error and variance
mse = mean_squared_error(y_test, GCV_pred)
print(r2_score(y_test,GCV_pred)*100)
print("RMSE :",np.sqrt(mse))
# Out:
# 17.895936798012315
# RMSE : 37.189610821113874

# %%
print('best_pram', GCV.best_params_)
# Out:
# best_pram {'learning_rate': 0.1, 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor(learning_rate= 0.27,max_depth = 2, min_samples_leaf =  2, min_samples_split=2,random_state=859,ccp_alpha=0.0
                               ,max_features=4,n_estimators=139)
gb.fit(x_train,y_train)

pred = gb.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 29.465465423483785
# 28.910858941297523
# RMSE : 35.74077957330815

# %%
### from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(min_impurity_decrease=0.0,ccp_alpha=0.0,min_samples_split=2,random_state=859,max_depth=8,max_features=4)
dt.fit(x_train,y_train)
pred = dt.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# 16.5562879110984
# 29.700198912794065
# RMSE : 37.398450739696

# %%
test_data = pd.read_csv('test_6QvDdzb.csv')
test_data.head()
# Out:
#          date  hour
# 0  2021-03-01     0
# 1  2021-03-01     1
# 2  2021-03-01     2
# 3  2021-03-01     3
# 4  2021-03-01     5

# %%
test_data.shape
# Out:
# (7650, 2)

# %%
test_data['date'] = pd.to_datetime(test_data['date'], errors='coerce')

# %%
test_data['day-of-week'] = test_data['date'].dt.dayofweek

# %%
test_data['week-of-year'] = test_data['date'].dt.weekofyear

# %%
test_data
# Out:
#            date  hour  day-of-week  week-of-year
# 0    2021-03-01     0            0             9
# 1    2021-03-01     1            0             9
# 2    2021-03-01     2            0             9
# 3    2021-03-01     3            0             9
# 4    2021-03-01     5            0             9
# ...         ...   ...          ...           ...
# 7645 2022-03-28    19            0            13
# 7646 2022-03-28    20            0            13
# 7647 2022-03-28    21            0            13
# 7648 2022-03-28    22            0            13
# 7649 2022-03-28    23            0            13
#
# [7650 rows x 4 columns]

# %%
demand_day = []
for i in range(len(test_data['day-of-week'])):
    if test_data['day-of-week'][i] <=3:
        demand_day.append("Low")
    else:
        demand_day.append("High")

# %%
test_data['demand_day'] = demand_day

# %%
test_data
# Out:
#            date  hour  day-of-week  week-of-year demand_day
# 0    2021-03-01     0            0             9        Low
# 1    2021-03-01     1            0             9        Low
# 2    2021-03-01     2            0             9        Low
# 3    2021-03-01     3            0             9        Low
# 4    2021-03-01     5            0             9        Low
# ...         ...   ...          ...           ...        ...
# 7645 2022-03-28    19            0            13        Low
# 7646 2022-03-28    20            0            13        Low
# 7647 2022-03-28    21            0            13        Low
# 7648 2022-03-28    22            0            13        Low
# 7649 2022-03-28    23            0            13        Low
#
# [7650 rows x 5 columns]

# %% [markdown]
# # changing in zones

# %%
demand_zone = []
for i in range(len(test_data['hour'])):
    if test_data['hour'][i] < 6 or test_data['hour'][i]>=22:
        demand_zone.append("Low")
    elif 6<=test_data['hour'][i]<=12 or 18<=test_data['hour'][i]<=22 :
        demand_zone.append("Medium")
    else:
        demand_zone.append("High")

# %%
test_data['demand_zone'] = demand_zone

# %%
### Label encoder in test data'
from sklearn.preprocessing import LabelEncoder
lab_enc = LabelEncoder()
test_data['demand_day'] = lab_enc.fit_transform(test_data['demand_day'])

# %%
test_data = pd.get_dummies(test_data)

# %%
test_data
# Out:
#            date  hour  day-of-week  week-of-year  demand_day  \
# 0    2021-03-01     0            0             9           1
# 1    2021-03-01     1            0             9           1
# 2    2021-03-01     2            0             9           1
# 3    2021-03-01     3            0             9           1
# 4    2021-03-01     5            0             9           1
# ...         ...   ...          ...           ...         ...
# 7645 2022-03-28    19            0            13           1
# 7646 2022-03-28    20            0            13           1
# 7647 2022-03-28    21            0            13           1
# 7648 2022-03-28    22            0            13           1
# 7649 2022-03-28    23            0            13           1
#
#       demand_zone_High  demand_zone_Low  demand_zone_Medium
# 0                    0                1                   0
# 1                    0                1                   0
# 2                    0                1                   0
# 3                    0                1                   0
# 4                    0                1                   0
# ...                ...              ...                 ...
# 7645                 0                0                   1
# 7646                 0                0                   1
# 7647                 0                0                   1
# 7648                 0                1                   0
# 7649                 0                1                   0
#
# [7650 rows x 8 columns]

# %%
X_test = test_data.drop(columns=['date'])

# %%
X_test.shape
# Out:
# (7650, 7)

# %%
pred = rf.predict(X_test)

# %%
pred
# Out:
# array([53.34261553, 53.03646437, 52.73512   , ..., 63.00281244,
#        58.24381011, 57.54120981])

# %%
submission_file = pd.read_csv('sample_4E0BhPN.csv')
submission_file
# Out:
#             date  hour  demand
# 0     2021-03-01     0       0
# 1     2021-03-01     1       0
# 2     2021-03-01     2       0
# 3     2021-03-01     3       0
# 4     2021-03-01     5       0
# ...          ...   ...     ...
# 7645  2022-03-28    19       0
# 7646  2022-03-28    20       0
# 7647  2022-03-28    21       0
# 7648  2022-03-28    22       0
# 7649  2022-03-28    23       0
#
# [7650 rows x 3 columns]

# %%
submission_file.shape
# Out:
# (7650, 3)

# %%
submission_file['demand'] = pred

# %%
pred.shape
# Out:
# (7650,)

# %%
submission_file
# Out:
#             date  hour     demand
# 0     2021-03-01     0  53.342616
# 1     2021-03-01     1  53.036464
# 2     2021-03-01     2  52.735120
# 3     2021-03-01     3  52.591385
# 4     2021-03-01     5  51.836044
# ...          ...   ...        ...
# 7645  2022-03-28    19  79.193095
# 7646  2022-03-28    20  69.647080
# 7647  2022-03-28    21  63.002812
# 7648  2022-03-28    22  58.243810
# 7649  2022-03-28    23  57.541210
#
# [7650 rows x 3 columns]

# %%
submission_file.to_csv("rf 12th model.csv",index=False)

# %%
submission_file.shape
# Out:
# (7650, 3)
